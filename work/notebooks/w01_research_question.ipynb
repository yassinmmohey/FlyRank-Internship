# %% [markdown]
# <a href="https://colab.research.google.com/github/yassinmmohey/FlyRank-Internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yassinmmohey/FlyRank-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane 2: Refresh / Content Opportunity Scoring. "which pages should be reviewed first for a refresh?" is an everyday decision a content team actually makes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Imagine a team that manages a massive website, but only has enough time to update a few pages each week. They use an automated alert system to tell them which pages are losing visitors and need fixing. Sometimes, the system makes a mistake. If it sounds the alarm for a page that is actually fine, the team just wastes a few minutes double-checking it. However, if the system fails to warn them about a page that is genuinely failing, the website silently bleeds traffic for weeks. Because missing a real problem hurts much more than doing a quick, unnecessary check, the alert system is programmed to be overly cautious. It will flag any page that looks even slightly suspicious, just to be safe.**

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# 1.   54.2% of pages are labeled "declining" that's a huge, real problem, not a rare edge case. More than half the content in this dataset shows a downward trend, which means a review-prioritization tool has plenty to work with.
#
# 2.   16,726 pages (over half) have real search visibility (≥500 impressions in 90 days) this rules out the concern that you're prioritizing pages nobody sees anyway. There's a large pool of visible, worth-fixing content.
#
#
# 1.  32 clients gives you enough variety to do a proper client holdout validation later (testing on clients the model has never seen), which the guide flags as important for honest results.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total rows:", len(df))
print("Unique clients:", df['client_id'].nunique())
print("Declining pages (%):", round((df['trend_direction'] == 'down').mean() * 100, 1))
print("Pages with impressions_90d >= 500:", (df['impressions_90d'] >= 500).sum())
# Out:
# Total rows: 30000
# Unique clients: 32
# Declining pages (%): 54.2
# Pages with impressions_90d >= 500: 16726

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# **What I can say:** My work looks at real, past data and points out pages that already show signs of losing traffic or clicks. It gives a ranked list so a team knows which pages to check first. These are patterns I observed in the data not predictions.
#
# **What I can't say:** I cannot say that fixing a page will definitely bring its traffic back that would need a real test (like actually fixing some pages and comparing them to ones left alone), not just this data. I also cannot say I know how Google's ranking system works, or that I'm "predicting Google." I'm only showing what already happened in the past, and using that to guess what's worth looking at next.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
